# %% [markdown]
# # CSS Citation Sentiment Example (10/21)
#
# Overview: this is part of a larger project of Jeremy Freese's that involves documenting the characteristics of "null fields" of scientific research. This notebook details a particular feature of this project - citation sentiment analysis - and its application to a few papers. The code and methodological details for the sentiment analysis are taken from Kilacoglu et al (2020); see their paper here: https://www.sciencedirect.com/science/article/pii/S1532046419300413?via%3Dihub and their github here: https://github.com/kilicogluh/clinical-citation-sentiment

# %%
#######################################################
# code summary: the goal of this code is to develop a
# citation network around candidate genes
#######################################################

# set working directory to the GitHub
import os
os.chdir('C:\\Users\\tyler\\Documents\\GitHub\\Wallaroo\\Gene_cites')

# %% [markdown]
# ### First, find papers in PubMed that cite our paper of interest

# %%
# identify articles in the open access subset that were published since 2000
pmid = 12869766
db = "pubmed" # Caspi et al is in the pubmed set, but later we'll use PMC
retmode = "json"

# articles that cite the paper - don't loop this command (due to robots.txt restrictions)
tup = ("https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi?dbfrom=",db,
      "&linkname=pubmed_pmc_refs&id=", pmid)

url = ''.join(map(str, tup))
print(url)
# Out:
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi?dbfrom=pubmed&linkname=pubmed_pmc_refs&id=12869766

# %%
# now, put our output in beautifulsoup format
from bs4 import BeautifulSoup
from urllib.request import urlopen
html = urlopen(url)
bs = BeautifulSoup(html.read(), 'xml')
# find ids within set of citations 
idlist = bs.find('LinkSetDb').find_all('Id',{}) # (excluding original paper id)    

# print the PMC ids of articles that cite Caspi et al (only first 10)
print(len(idlist)) # 1595 citations
print(idlist[:10])
# Out:
# 1713
# [<Id>7555071</Id>, <Id>7539902</Id>, <Id>7537828</Id>, <Id>7524411</Id>, <Id>7508939</Id>, <Id>7501125</Id>, <Id>7474769</Id>, <Id>7450762</Id>, <Id>7446184</Id>, <Id>7445164</Id>]

# %% [markdown]
# ### Next, pull the full text of those papers (if they are in the open access subset)

# %%
# this code would be within a function, to run on the entire list of ids from the above code
id = idlist[0]
cite_tup = ("https://www.ncbi.nlm.nih.gov/pmc/oai/oai.cgi?verb=GetRecord&identifier=oai:pubmedcentral.nih.gov:",
id.get_text(),"&metadataPrefix=pmc")
cite_url = ''.join(map(str,cite_tup))
print(cite_url)
# Out:
# https://www.ncbi.nlm.nih.gov/pmc/oai/oai.cgi?verb=GetRecord&identifier=oai:pubmedcentral.nih.gov:7555071&metadataPrefix=pmc

# %%
import pandas as pd
# now we begin to extract citing sentences
# look in pmc, because these have full text available
sentences_df = pd.read_csv("sentences_df.txt", header = None, sep = "jfdkls;fjasi;osjeioa;")

# rename column
sentences_df = sentences_df.rename(columns = {0:'Citing Sentence'})

sentences_df[:10]
# Out:
# C:\Users\tyler\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
#                                      Citing Sentence
# 0  The 5-HT gene could moderate the serotonergic ...
# 1  Nevertheless, a 23-year longitudinal study has...
# 2  As with symptom syndromes, whether environment...
# 3  On the other hand, the lasting effects of earl...
# 4  Other genetically-mediated neurobiological var...
# 5  <cit id="2687817">[B32]</cit> Therefore, furth...
# 6  Hence, while numerous experimental and clinica...
# 7  Research on GE correlation will be greatly adv...
# 8  For instance, the chances to develop an episod...
# 9  Many studies have linked these VNTRs with diso...

# %% [markdown]
# ## The following code imports journal information and citation sentences

# %%
# import data with journal names, ids, and citescores
cs_df = pd.read_csv("cs_df.csv")

# import citation sentences with sentiments
sentences_df_corder = pd.read_csv("clinical-citation-sentiment-master\\sentences_df_corder.csv")
sentences_df_corder['paper'] = "corder"

sentences_df_caspi = pd.read_csv("clinical-citation-sentiment-master\\sentences_df_caspi.csv")
sentences_df_caspi['paper'] = "caspi"

sentences_df_lesch = pd.read_csv("clinical-citation-sentiment-master\\sentences_df_lesch.csv")
sentences_df_lesch['paper'] = "lesch"

sentences_df_strittmatter = pd.read_csv("clinical-citation-sentiment-master\\sentences_df_strittmatter.csv")
sentences_df_strittmatter['paper'] = "strittmatter"

# merge data with all papers
sentences_df = pd.concat([sentences_df_corder, sentences_df_caspi, sentences_df_lesch, sentences_df_strittmatter])
# Out:
# C:\Users\tyler\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %%
# change name to MedAbbr
sentences_df = sentences_df.rename(columns={"journal": "MedAbbr"})

# pull out year, month, day
date_expanded = sentences_df.pub_date.str.split(" ") 

# add blanks for items missing dates
for elem in date_expanded:
    for i in range(3 - len(elem)):
        elem.append("")


# may need to do an ['extra'] column as well here, and drop it, depending on how dates are listed
sentences_df[['Year', 'Month', 'Day']] = pd.DataFrame(date_expanded.tolist(),
                                                              index= date_expanded.index)

# get rid of unnecessary column
#sentences_df = sentences_df.drop(['Extra'], axis = 1)

sentences_df
# Out:
#     Day Month  Year  cit_sent       cite_id cite_id_check  \
# 0    29   Sep  2020   NEUTRAL         bib11         bib11
# 1    28   Sep  2020   NEUTRAL           NaN           NaN
# 2    27   Sep  2020   NEUTRAL            B4            B4
# 3    22   Sep  2020   NEUTRAL           NaN           NaN
# 4    22   Sep  2020   NEUTRAL          CR13          CR13
# 5    22   Sep  2020   NEUTRAL          CR13          CR13
# 6    22   Sep  2020  POSITIVE          CR13          CR13
# 7     4   Aug  2020   NEUTRAL        ref003        ref003
# 8     1   Sep  2020   NEUTRAL           NaN           NaN
# 9     3   Sep  2020   NEUTRAL           B41           B41
# 10   11   Sep  2020   NEUTRAL          CR22          CR22
# 11   21   Aug  2020   NEUTRAL           B16           B16
# 12   27   Aug  2020   NEUTRAL  DMM045211C56  DMM045211C56
# 13   21   Aug  2020   NEUTRAL           B23           B23
# 14   27   Aug  2020   NEUTRAL          CR51          CR51
# 15   28   Aug  2020   NEUTRAL            R3            R3
# 16   28   Aug  2020   NEUTRAL            R3            R3
# 17   28   Aug  2020   NEUTRAL            R3            R3
# 18   21   Jul  2020   NEUTRAL           NaN           NaN
# 19   30   May  2020   NEUTRAL           NaN           NaN
# 20    2   Jul  2020   NEUTRAL         bib11         bib11
# 21    2   Jul  2020   NEUTRAL         bib11         bib11
# 22    7   Aug  2020   NEUTRAL           CR1           CR1
# 23   31   Jul  2020   NEUTRAL           B10           B10
# 24   17   Jul  2020   NEUTRAL           NaN           NaN
# 25   24   Jun  2020  POSITIVE         bib12         bib12
# 26   24   Jun  2020  POSITIVE         bib12         bib12
# 27   24   Jun  2020   NEUTRAL         bib12         bib12
# 28   24   Jun  2020   NEUTRAL         bib12         bib12
# 29        May  2020   NEUTRAL          r101          r101
# ..   ..   ...   ...       ...           ...           ...
# 265  10   Jan  2011   NEUTRAL           B17           B17
# 266   2   Dec  2010   NEUTRAL            B7            B7
# 267  29   Oct  2010   NEUTRAL            B3            B3
# 268  29   Oct  2010   NEUTRAL            B3            B3
# 269  29   Jun  2010  POSITIVE          CR25          CR25
# 270  14   Jul  2010   NEUTRAL           B64           B64
# 271  15   Jul  2010   NEUTRAL            51           B53
# 272  13   Apr  2010   NEUTRAL     DDQ142C34     DDQ142C34
# 273   5   Mar  2010   NEUTRAL            30           B31
# 274  20   Feb  2010   NEUTRAL            B5            B5
# 275   3   Sep  2009   NEUTRAL           B73           B73
# 276  15   Sep  2009   NEUTRAL            B8            B8
# 277  20   Aug  2009   NEUTRAL            B1            B1
# 278  20   Aug  2009   NEUTRAL            B1            B1
# 279  27   May  2009   NEUTRAL            B3            B3
# 280  27   Mar  2009   NEUTRAL           B13           B13
# 281   3   Dec  2008   NEUTRAL           B34           B34
# 282   6   Oct  2008   NEUTRAL           B65           B65
# 283  16   Apr  2008   NEUTRAL            B7            B7
# 284   6   Jan  2003   NEUTRAL         bib60         bib60
# 285  16   Nov  2007   NEUTRAL         CR291         CR291
# 286   6   Jul  2007   NEUTRAL          CR27          CR27
# 287   9   Jul  2007   NEUTRAL           B24           B24
# 288  15   May  2007   NEUTRAL            B1            B1
# 289  12   Apr  2007  POSITIVE            B2            B2
# 290  18   Aug  2006   NEUTRAL           B37           B37
# 291            2005   NEUTRAL            B4            B4
# 292  27   Jun  2005   NEUTRAL            b5            b5
# 293  30   Nov  2004   NEUTRAL           B16           B16
# 294   2   Jun  2004  POSITIVE           B17           B17
#
#                                        citing sentence       id  \
# 0    In addition, ZIC1 and ZIC2 transactivate apoli...  7527782
# 1    1 , <cit id="7521596">[dad212110-bib-0002]</ci...  7521596
# 2    Furthermore, some polymorphisms have been impl...  7520642
# 3    <cit id="7508460">[dad212094-bib-0001]</cit> O...  7508460
# 4    Although the clinical onset of AD usually occu...  7507658
# 5    In this line, ε4 carriage has been associated ...  7507658
# 6    However, mean age in our sample, even in the o...  7507658
# 7    The apolipoprotein E (APOE) gene is the most i...  7504994
# 8    In humans, the APOE gene has three common alle...  7503657
# 9    Interestingly, Pyun et al. (2019) found a stro...  7494756
# 10   There are three major APOE alleles in humans, ...  7488504
# 11   For example, female APOE ε4 carriers (FACs) ha...  7482805
# 12   APOE ε4 is associated with earlier disease ons...  7473656
# 13   The three APOE isoforms accelerate the deposit...  7471745
# 14   For example, with the ε4 allele being an AD ri...  7457273
# 15   The ε4 allele of the apolipoprotein E (APOE) g...  7455192
# 16   For analyses, we focused on two genetic subgro...  7455192
# 17   For analyses, we focused on two genetic subgro...  7455192
# 18   41 , <cit id="7448143">[acn351120-bib-0042]</cit>  7448143
# 19   Among an increasing number of genes implicated...  7434743
# 20   <cit id="7425753">[bib11]</cit>,12 More recent...  7425753
# 21   We selected the APOE ε2, ε3, and ε4 alleles fo...  7425753
# 22   The apolipoprotein E (APOE) e4 allele is the m...  7414226
# 23   ApoER2 binds the secreted lipid carrier apolip...  7410921
# 24   The existence of APOE polymorphisms have a dir...  7407646
# 25   The strongest genetic risk factor for the more...  7407474
# 26   The lifetime risk for AD in people homozygous ...  7407474
# 27   This retains the variant-specific effect of AP...  7407474
# 28   In humans, the allele ε4 of APOE (APOE4) incre...  7407474
# 29   Cholesterol’s role in AD remained largely igno...  7403650
# ..                                                 ...      ...
# 265  ApoE4 has been found to interact with beta-amy...  3022805
# 266  In addition to the effects of amyloid plaques ...  2997345
# 267  The most significant genetic association repor...  2988784
# 268  Genetic and biochemical evidence suggest that ...  2988784
# 269  The discovery of APOE’s involvement in LOAD an...  2987528
# 270  An interesting link with regard to this is the...  2949586
# 271  In CSF Aβ may either exist as a free soluble p...  2925386
# 272  The genetic complexity of late-onset AD is und...  2875058
# 273  APOE is a component of senile plaques [30], bi...  2874262
# 274  ApoE4 is a major genetic risk factor for late-...  2837047
# 275  An example is homozygosity in the APOE4 allele...  2768980
# 276  To date, the main genetic risk factor for late...  2753310
# 277  It has been shown that the prevalence of Alzhe...  2739857
# 278  It is well known that the possession of apoE4 ...  2739857
# 279  In contrast, apoE2 expression decreases diseas...  2695436
# 280  After observing high-avidity binding of Aβ to ...  2664945
# 281  ApoE binds hydrophobically to amino acids 12–2...  2604889
# 282  Finally and intriguingly, mammals other than h...  2576240
# 283  Carrying the APOE ε4 allele is a risk factor f...  2375917
# 284  The E4 allele of apolipoprotein E has been sho...  2172747
# 285  Much was expected of studies using Tg mice to ...  2100431
# 286  In vitro studies provided evidence for a direc...  2039847
# 287  Several lines of evidence support a role for t...  1939850
# 288  It has been shown that the prevalence of Alzhe...  1876452
# 289  In comparison to people who are homozygous for...  1857699
# 290  Interestingly, apoE exists in three isoforms (...  1563464
# 291  The  established genetic risk factor is the E4...  1184050
# 292  In fact, several complex genetic disorders suc...  1165690
# 293  The APOE ε4 allele is also considered a strong...   539242
# 294  These individuals were also genotyped for codi...   420466
#
#                        MedAbbr         paper      pmc_id     pub_date  \
# 0                     Cell Rep        corder  PMC7527782  2020 Sep 29
# 1     Alzheimers Dement (Amst)        corder  PMC7521596  2020 Sep 28
# 2            World J Biol Chem        corder  PMC7520642  2020 Sep 27
# 3     Alzheimers Dement (Amst)        corder  PMC7508460  2020 Sep 22
# 4          Alzheimers Res Ther        corder  PMC7507658  2020 Sep 22
# 5          Alzheimers Res Ther        corder  PMC7507658  2020 Sep 22
# 6          Alzheimers Res Ther        corder  PMC7507658  2020 Sep 22
# 7             J Alzheimers Dis        corder  PMC7504994   2020 Aug 4
# 8                Int J Mol Sci        corder  PMC7503657   2020 Sep 1
# 9               Front Neurosci        corder  PMC7494756   2020 Sep 3
# 10                 Biomark Res        corder  PMC7488504  2020 Sep 11
# 11                Theranostics        corder  PMC7482805  2020 Aug 21
# 12              Dis Model Mech        corder  PMC7473656  2020 Aug 27
# 13          Front Mol Neurosci        corder  PMC7471745  2020 Aug 21
# 14            Clin Epigenetics        corder  PMC7457273  2020 Aug 27
# 15                     Sci Adv        corder  PMC7455192  2020 Aug 28
# 16                     Sci Adv        corder  PMC7455192  2020 Aug 28
# 17                     Sci Adv        corder  PMC7455192  2020 Aug 28
# 18      Ann Clin Transl Neurol        corder  PMC7448143  2020 Jul 21
# 19       Mol Genet Genomic Med        corder  PMC7434743  2020 May 30
# 20   Invest Ophthalmol Vis Sci        corder  PMC7425753   2020 Jul 2
# 21   Invest Ophthalmol Vis Sci        corder  PMC7425753   2020 Jul 2
# 22                     Sci Rep        corder  PMC7414226   2020 Aug 7
# 23          Front Mol Neurosci        corder  PMC7410921  2020 Jul 31
# 24                       Cells        corder  PMC7407646  2020 Jul 17
# 25               G3 (Bethesda)        corder  PMC7407474  2020 Jun 24
# 26               G3 (Bethesda)        corder  PMC7407474  2020 Jun 24
# 27               G3 (Bethesda)        corder  PMC7407474  2020 Jun 24
# 28               G3 (Bethesda)        corder  PMC7407474  2020 Jun 24
# 29              Curr Aging Sci        corder  PMC7403650     2020 May
# ..                         ...           ...         ...          ...
# 265               J Biomed Sci  strittmatter  PMC3022805  2011 Jan 10
# 266       Int J Alzheimers Dis  strittmatter  PMC2997345   2010 Dec 2
# 267           Mol Neurodegener  strittmatter  PMC2988784  2010 Oct 29
# 268           Mol Neurodegener  strittmatter  PMC2988784  2010 Oct 29
# 269                     EPMA J  strittmatter  PMC2987528  2010 Jun 29
# 270        Alzheimers Res Ther  strittmatter  PMC2949586  2010 Jul 14
# 271       Int J Alzheimers Dis  strittmatter  PMC2925386  2010 Jul 15
# 272              Hum Mol Genet  strittmatter  PMC2875058  2010 Apr 13
# 273        Alzheimers Res Ther  strittmatter  PMC2874262   2010 Mar 5
# 274               BMC Neurosci  strittmatter  PMC2837047  2010 Feb 20
# 275                Genome Biol  strittmatter  PMC2768980   2009 Sep 3
# 276              BMC Med Genet  strittmatter  PMC2753310  2009 Sep 15
# 277           Mol Neurodegener  strittmatter  PMC2739857  2009 Aug 20
# 278           Mol Neurodegener  strittmatter  PMC2739857  2009 Aug 20
# 279           Mol Neurodegener  strittmatter  PMC2695436  2009 May 27
# 280                 Genome Med  strittmatter  PMC2664945  2009 Mar 27
# 281               BMC Neurosci  strittmatter  PMC2604889   2008 Dec 3
# 282              BMC Evol Biol  strittmatter  PMC2576240   2008 Oct 6
# 283                 BMC Neurol  strittmatter  PMC2375917  2008 Apr 16
# 284                J Cell Biol  strittmatter  PMC2172747   2003 Jan 6
# 285           Acta Neuropathol  strittmatter  PMC2100431  2007 Nov 16
# 286              Mol Neurobiol  strittmatter  PMC2039847   2007 Jul 6
# 287           Mol Neurodegener  strittmatter  PMC1939850   2007 Jul 9
# 288           Mol Neurodegener  strittmatter  PMC1876452  2007 May 15
# 289           Mol Neurodegener  strittmatter  PMC1857699  2007 Apr 12
# 290           Mol Neurodegener  strittmatter  PMC1563464  2006 Aug 18
# 291        J Biomed Biotechnol  strittmatter  PMC1184050         2005
# 292          Nucleic Acids Res  strittmatter  PMC1165690  2005 Jun 27
# 293          Lipids Health Dis  strittmatter   PMC539242  2004 Nov 30
# 294              BMC Med Genet  strittmatter   PMC420466   2004 Jun 2
#
#      pubmed_id
# 0     32997995
# 1     33015312
# 2     33024518
# 3     32999914
# 4     32962736
# 5     32962736
# 6     32962736
# 7     32568201
# 8     32882843
# 9     33013301
# 10    32944245
# 11    32929366
# 12    32859588
# 13    32973449
# 14    32854783
# 15    32923622
# 16    32923622
# 17    32923622
# 18    32856790
# 19    32472747
# 20    32614373
# 21    32614373
# 22    32770103
# 23    32848602
# 24    32709045
# 25    32580938
# 26    32580938
# 27    32580938
# 28    32580938
# 29    31530269
# ..         ...
# 265   21219628
# 266   21151659
# 267   21034469
# 268   21034469
# 269   21124753
# 270   20642866
# 271   20798852
# 272   20388643
# 273   20236449
# 274   20170526
# 275   19728866
# 276   19754925
# 277   19695092
# 278   19695092
# 279   19725929
# 280   19341505
# 281   19090993
# 282   18837980
# 283   18416843
# 284   12515826
# 285   18038275
# 286   17917109
# 287   17620134
# 288   17504523
# 289   17430597
# 290   16930455
# 291   16046825
# 292   15980522
# 293   15571629
# 294   15175114
#
# [2442 rows x 13 columns]

# %% [markdown]
# ## Now, merge the journal info with citation sentences

# %%
# now merge journal information and citing sentences
sentences_cs_df = cs_df.merge(sentences_df, 'right')

sentences_cs_df
# Out:
#         index  CiteScore  E-ISSN ISSN (Online) ISSN (Print)  \
# 0        95.0   4.655556     NaN     0219-1032    1016-8478
# 1        95.0   4.655556     NaN     0219-1032    1016-8478
# 2        95.0   4.655556     NaN     0219-1032    1016-8478
# 3        95.0   4.655556     NaN     0219-1032    1016-8478
# 4        95.0   4.655556     NaN     0219-1032    1016-8478
# 5        95.0   4.655556     NaN     0219-1032    1016-8478
# 6        95.0   4.655556     NaN     0219-1032    1016-8478
# 7       293.0   9.511111     NaN     1476-5497    0307-0565
# 8       293.0   9.511111     NaN     1476-5497    0307-0565
# 9       293.0   9.511111     NaN     1476-5497    0307-0565
# 10      360.0   6.888889     NaN     1573-2827    1096-4037
# 11      374.0   5.366667     NaN     1531-135X    1530-7026
# 12      374.0   5.366667     NaN     1531-135X    1530-7026
# 13      412.0  13.644444     NaN     1545-7885    1544-9173
# 14      510.0   9.022222     NaN     1573-7284    0393-2990
# 15      530.0   2.877778     NaN     0717-6287    0716-9760
# 16      530.0   2.877778     NaN     0717-6287    0716-9760
# 17      530.0   2.877778     NaN     0717-6287    0716-9760
# 18      530.0   2.877778     NaN     0717-6287    0716-9760
# 19      530.0   2.877778     NaN     0717-6287    0716-9760
# 20      677.0  12.000000     NaN     1471-2970    0962-8436
# 21      741.0   3.588889     NaN     1531-4995    0023-852X
# 22      786.0  11.366667     NaN     1420-9071    1420-682X
# 23      786.0  11.366667     NaN     1420-9071    1420-682X
# 24      786.0  11.366667     NaN     1420-9071    1420-682X
# 25      786.0  11.366667     NaN     1420-9071    1420-682X
# 26      786.0  11.366667     NaN     1420-9071    1420-682X
# 27      786.0  11.366667     NaN     1420-9071    1420-682X
# 28      786.0  11.366667     NaN     1420-9071    1420-682X
# 29      786.0  11.366667     NaN     1420-9071    1420-682X
# ...       ...        ...     ...           ...          ...
# 2412  31988.0        NaN     NaN     2090-8601    2090-858X
# 2413  31988.0        NaN     NaN     2090-8601    2090-858X
# 2414  31988.0        NaN     NaN     2090-8601    2090-858X
# 2415  31988.0        NaN     NaN     2090-8601    2090-858X
# 2416  32073.0        NaN     NaN     2373-7972    2373-8006
# 2417  32689.0        NaN     NaN     2515-2092    2515-2084
# 2418  32714.0        NaN     NaN     2384-0757    1738-1495
# 2419  32714.0        NaN     NaN     2384-0757    1738-1495
# 2420  32714.0        NaN     NaN     2384-0757    1738-1495
# 2421  32714.0        NaN     NaN     2384-0757    1738-1495
# 2422  32714.0        NaN     NaN     2384-0757    1738-1495
# 2423  32714.0        NaN     NaN     2384-0757    1738-1495
# 2424  32714.0        NaN     NaN     2384-0757    1738-1495
# 2425      NaN        NaN     NaN           NaN          NaN
# 2426      NaN        NaN     NaN           NaN          NaN
# 2427      NaN        NaN     NaN           NaN          NaN
# 2428      NaN        NaN     NaN           NaN          NaN
# 2429      NaN        NaN     NaN           NaN          NaN
# 2430      NaN        NaN     NaN           NaN          NaN
# 2431      NaN        NaN     NaN           NaN          NaN
# 2432      NaN        NaN     NaN           NaN          NaN
# 2433      NaN        NaN     NaN           NaN          NaN
# 2434      NaN        NaN     NaN           NaN          NaN
# 2435      NaN        NaN     NaN           NaN          NaN
# 2436      NaN        NaN     NaN           NaN          NaN
# 2437      NaN        NaN     NaN           NaN          NaN
# 2438      NaN        NaN     NaN           NaN          NaN
# 2439      NaN        NaN     NaN           NaN          NaN
# 2440      NaN        NaN     NaN           NaN          NaN
# 2441      NaN        NaN     NaN           NaN          NaN
#
#                                           IsoAbbr  \
# 0                                      Mol. Cells
# 1                                      Mol. Cells
# 2                                      Mol. Cells
# 3                                      Mol. Cells
# 4                                      Mol. Cells
# 5                                      Mol. Cells
# 6                                      Mol. Cells
# 7                               Int J Obes (Lond)
# 8                               Int J Obes (Lond)
# 9                               Int J Obes (Lond)
# 10                     Clin Child Fam Psychol Rev
# 11                     Cogn Affect Behav Neurosci
# 12                     Cogn Affect Behav Neurosci
# 13                                     PLoS Biol.
# 14                             Eur. J. Epidemiol.
# 15                                     Biol. Res.
# 16                                     Biol. Res.
# 17                                     Biol. Res.
# 18                                     Biol. Res.
# 19                                     Biol. Res.
# 20    Philos. Trans. R. Soc. Lond., B, Biol. Sci.
# 21                                   Laryngoscope
# 22                           Cell. Mol. Life Sci.
# 23                           Cell. Mol. Life Sci.
# 24                           Cell. Mol. Life Sci.
# 25                           Cell. Mol. Life Sci.
# 26                           Cell. Mol. Life Sci.
# 27                           Cell. Mol. Life Sci.
# 28                           Cell. Mol. Life Sci.
# 29                           Cell. Mol. Life Sci.
# ...                                           ...
# 2412                           J Neurodegener Dis
# 2413                           J Neurodegener Dis
# 2414                           J Neurodegener Dis
# 2415                           J Neurodegener Dis
# 2416                                AIMS Neurosci
# 2417                    J Can Assoc Gastroenterol
# 2418                      Dement Neurocogn Disord
# 2419                      Dement Neurocogn Disord
# 2420                      Dement Neurocogn Disord
# 2421                      Dement Neurocogn Disord
# 2422                      Dement Neurocogn Disord
# 2423                      Dement Neurocogn Disord
# 2424                      Dement Neurocogn Disord
# 2425                                          NaN
# 2426                                          NaN
# 2427                                          NaN
# 2428                                          NaN
# 2429                                          NaN
# 2430                                          NaN
# 2431                                          NaN
# 2432                                          NaN
# 2433                                          NaN
# 2434                                          NaN
# 2435                                          NaN
# 2436                                          NaN
# 2437                                          NaN
# 2438                                          NaN
# 2439                                          NaN
# 2440                                          NaN
# 2441                                          NaN
#
#                                            JournalTitle     JrId  \
# 0                                   Molecules and cells   8634.0
# 1                                   Molecules and cells   8634.0
# 2                                   Molecules and cells   8634.0
# 3                                   Molecules and cells   8634.0
# 4                                   Molecules and cells   8634.0
# 5                                   Molecules and cells   8634.0
# 6                                   Molecules and cells   8634.0
# 7               International journal of obesity (2005)  32579.0
# 8               International journal of obesity (2005)  32579.0
# 9               International journal of obesity (2005)  32579.0
# 10          Clinical child and family psychology review  22026.0
# 11       Cognitive, affective & behavioral neuroscience  30089.0
# 12       Cognitive, affective & behavioral neuroscience  30089.0
# 13                                         PLoS biology  30470.0
# 14                     European journal of epidemiology   3672.0
# 15                                  Biological research   2441.0
# 16                                  Biological research   2441.0
# 17                                  Biological research   2441.0
# 18                                  Biological research   2441.0
# 19                                  Biological research   2441.0
# 20    Philosophical transactions of the Royal Societ...   8277.0
# 21                                     The Laryngoscope   5476.0
# 22          Cellular and molecular life sciences : CMLS  20436.0
# 23          Cellular and molecular life sciences : CMLS  20436.0
# 24          Cellular and molecular life sciences : CMLS  20436.0
# 25          Cellular and molecular life sciences : CMLS  20436.0
# 26          Cellular and molecular life sciences : CMLS  20436.0
# 27          Cellular and molecular life sciences : CMLS  20436.0
# 28          Cellular and molecular life sciences : CMLS  20436.0
# 29          Cellular and molecular life sciences : CMLS  20436.0
# ...                                                 ...      ...
# 2412              Journal of neurodegenerative diseases  43781.0
# 2413              Journal of neurodegenerative diseases  43781.0
# 2414              Journal of neurodegenerative diseases  43781.0
# 2415              Journal of neurodegenerative diseases  43781.0
# 2416                                  AIMS neuroscience  44209.0
# 2417  Journal of the Canadian Association of Gastroe...  48298.0
# 2418              Dementia and neurocognitive disorders  48446.0
# 2419              Dementia and neurocognitive disorders  48446.0
# 2420              Dementia and neurocognitive disorders  48446.0
# 2421              Dementia and neurocognitive disorders  48446.0
# 2422              Dementia and neurocognitive disorders  48446.0
# 2423              Dementia and neurocognitive disorders  48446.0
# 2424              Dementia and neurocognitive disorders  48446.0
# 2425                                                NaN      NaN
# 2426                                                NaN      NaN
# 2427                                                NaN      NaN
# 2428                                                NaN      NaN
# 2429                                                NaN      NaN
# 2430                                                NaN      NaN
# 2431                                                NaN      NaN
# 2432                                                NaN      NaN
# 2433                                                NaN      NaN
# 2434                                                NaN      NaN
# 2435                                                NaN      NaN
# 2436                                                NaN      NaN
# 2437                                                NaN      NaN
# 2438                                                NaN      NaN
# 2439                                                NaN      NaN
# 2440                                                NaN      NaN
# 2441                                                NaN      NaN
#
#                                  MedAbbr      NlmId    ...     Year  cit_sent  \
# 0                              Mol Cells    9610936    ...     2019   NEUTRAL
# 1                              Mol Cells    9610936    ...     2019  POSITIVE
# 2                              Mol Cells    9610936    ...     2017   NEUTRAL
# 3                              Mol Cells    9610936    ...     2014   NEUTRAL
# 4                              Mol Cells    9610936    ...     2019  POSITIVE
# 5                              Mol Cells    9610936    ...     2019  POSITIVE
# 6                              Mol Cells    9610936    ...     2017   NEUTRAL
# 7                      Int J Obes (Lond)  101256108    ...     2019   NEUTRAL
# 8                      Int J Obes (Lond)  101256108    ...     2019   NEUTRAL
# 9                      Int J Obes (Lond)  101256108    ...     2012   NEUTRAL
# 10            Clin Child Fam Psychol Rev    9807947    ...     2015  POSITIVE
# 11            Cogn Affect Behav Neurosci  101083946    ...     2012   NEUTRAL
# 12            Cogn Affect Behav Neurosci  101083946    ...     2012   NEUTRAL
# 13                             PLoS Biol  101183755    ...     2008   NEUTRAL
# 14                       Eur J Epidemiol    8508062    ...     2019  POSITIVE
# 15                              Biol Res    9308271    ...     2016   NEUTRAL
# 16                              Biol Res    9308271    ...     2016   NEUTRAL
# 17                              Biol Res    9308271    ...     2016   NEUTRAL
# 18                              Biol Res    9308271    ...     2016   NEUTRAL
# 19                              Biol Res    9308271    ...     2016   NEUTRAL
# 20    Philos Trans R Soc Lond B Biol Sci    7503623    ...     2012   NEUTRAL
# 21                          Laryngoscope    8607378    ...     2014  NEGATIVE
# 22                     Cell Mol Life Sci    9705402    ...     2017   NEUTRAL
# 23                     Cell Mol Life Sci    9705402    ...     2017   NEUTRAL
# 24                     Cell Mol Life Sci    9705402    ...     2017   NEUTRAL
# 25                     Cell Mol Life Sci    9705402    ...     2017   NEUTRAL
# 26                     Cell Mol Life Sci    9705402    ...     2017   NEUTRAL
# 27                     Cell Mol Life Sci    9705402    ...     2013   NEUTRAL
# 28                     Cell Mol Life Sci    9705402    ...     2005   NEUTRAL
# 29                     Cell Mol Life Sci    9705402    ...     2017   NEUTRAL
# ...                                  ...        ...    ...      ...       ...
# 2412                  J Neurodegener Dis  101622104    ...     2013   NEUTRAL
# 2413                  J Neurodegener Dis  101622104    ...     2013   NEUTRAL
# 2414                  J Neurodegener Dis  101622104    ...     2013   NEUTRAL
# 2415                  J Neurodegener Dis  101622104    ...     2013   NEUTRAL
# 2416                       AIMS Neurosci  101665668    ...     2019   NEUTRAL
# 2417           J Can Assoc Gastroenterol  101738684    ...     2018   NEUTRAL
# 2418             Dement Neurocogn Disord  101600298    ...     2016   NEUTRAL
# 2419             Dement Neurocogn Disord  101600298    ...     2016   NEUTRAL
# 2420             Dement Neurocogn Disord  101600298    ...     2016   NEUTRAL
# 2421             Dement Neurocogn Disord  101600298    ...     2016   NEUTRAL
# 2422             Dement Neurocogn Disord  101600298    ...     2016   NEUTRAL
# 2423             Dement Neurocogn Disord  101600298    ...     2016   NEUTRAL
# 2424             Dement Neurocogn Disord  101600298    ...     2016   NEUTRAL
# 2425                               eLife        NaN    ...     2020   NEUTRAL
# 2426                               eLife        NaN    ...     2020   NEUTRAL
# 2427                               eLife        NaN    ...     2020   NEUTRAL
# 2428                               eLife        NaN    ...     2019  POSITIVE
# 2429                               eLife        NaN    ...     2019   NEUTRAL
# 2430                               eLife        NaN    ...     2019   NEUTRAL
# 2431                               eLife        NaN    ...     2018   NEUTRAL
# 2432                               eLife        NaN    ...     2018   NEUTRAL
# 2433                               eLife        NaN    ...     2018   NEUTRAL
# 2434                               eLife        NaN    ...     2017   NEUTRAL
# 2435                               eLife        NaN    ...     2017   NEUTRAL
# 2436                               eLife        NaN    ...     2013   NEUTRAL
# 2437                               eLife        NaN    ...     2013   NEUTRAL
# 2438                               eLife        NaN    ...     2016   NEUTRAL
# 2439                               eLife        NaN    ...     2019   NEUTRAL
# 2440                               eLife        NaN    ...     2017   NEUTRAL
# 2441              Front Neuroengineering        NaN    ...     2010   NEUTRAL
#
#               cite_id    cite_id_check  \
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
# 5                 NaN              NaN
# 6                 NaN              NaN
# 7                CR38             CR38
# 8                CR38             CR38
# 9                bib8             bib8
# 10              CR124            CR124
# 11               CR50             CR50
# 12               CR50             CR50
# 13                  1              NaN
# 14                 29             CR36
# 15               CR24             CR24
# 16               CR24             CR24
# 17                 67             CR24
# 18               CR24             CR24
# 19               CR97             CR97
# 20    RSTB20120094C17  RSTB20120094C17
# 21                NaN              NaN
# 22               CR51             CR15
# 23               CR51             CR51
# 24               CR51             CR51
# 25               CR51             CR51
# 26                151             CR51
# 27                127            CR128
# 28               CR39             CR39
# 29              CR282            CR282
# ...               ...              ...
# 2412               B8               B8
# 2413               B8               B8
# 2414               B1               B1
# 2415               B9               B9
# 2416              b33              b33
# 2417          CIT0012          CIT0012
# 2418              B13              B13
# 2419              B13              B13
# 2420              B13              B13
# 2421              B13              B13
# 2422              B13              B13
# 2423              B49              B49
# 2424              B49              B49
# 2425            bib18            bib18
# 2426            bib18            bib18
# 2427            bib18            bib18
# 2428            bib13            bib13
# 2429            bib13            bib13
# 2430            bib13            bib13
# 2431            bib16            bib16
# 2432            bib16            bib16
# 2433            bib16            bib16
# 2434             bib3             bib3
# 2435            bib11            bib11
# 2436             bib9             bib9
# 2437             bib9             bib9
# 2438             bib7             bib7
# 2439            bib48            bib48
# 2440            bib69            bib69
# 2441              B19              B19
#
#                                         citing sentence       id  \
# 0     Among identified genetic risk factors for LOAD...  6883979
# 1     Since its strong association with AD was first...  6883979
# 2     One major genetic risk factor for LO-SAD is th...  5638769
# 3     Rare apoE2 allele has a protective effect agai...  4255096
# 4     However, ApoE4 is one of the strongest risk fa...  6883979
# 5     Since its strong association with AD was first...  6883979
# 6     One major genetic risk factor for LO-SAD is th...  5638769
# 7     The short allele reduces transcription compare...  6522375
# 8     The short allele reduces transcription compare...  6522375
# 9     <cit id="3539149">[bib8]</cit> Consequently, a...  3539149
# 10    The S-allele has been related to significantly...  4637001
# 11    In addition to dopamine, previous research (Le...  3505534
# 12    A candidate gene for testing this hypothesis i...  3505534
# 13    In humans, gene–environment interactions have ...  2292755
# 14    Particularly genetic variants tagging PICALM c...  6497814
# 15    The age of onset of AD decreases with increasi...  4769573
# 16    The age of onset of AD decreases with increasi...  4769573
# 17    Within these isoforms ApoE 4 has been describe...  4769573
# 18    This allele has a single amino acid change wit...  4769573
# 19    The search in human cerebrospinal fluid for pr...  4769573
# 20    Genetic evidence also supports a role for poly...  3405679
# 21    <cit id="4758402">[lary24898-bib-0016]</cit>, ...  4758402
# 22    Effects on Aβb References APP FADc Rare  21q2 ...  5425508
# 23    The strongest known susceptibility locus for L...  5425508
# 24    Carriers of a single, and moreover, carriers o...  5425508
# 25    However, the exact role of ApoE in AD pathogen...  5425508
# 26    Evidence suggests that the APOE2 allele may be...  5425508
# 27    Gene–social environment interactions have been...  3809334
# 28    As an example of the importance of the functio...  2792355
# 29    In vitro studies have helped to elucidate the ...  5425508
# ...                                                 ...      ...
# 2412  The risk for AD is increased in carriers of th...  4437335
# 2413  The risk for AD is increased in carriers of th...  4437335
# 2414  In addition to genetic susceptibility genes, s...  4437336
# 2415  The risk for AD is increased in carriers of th...  4437335
# 2416  Individuals with its ε4 allele are at increase...  7179348
# 2417  We observed that the S-genotype, associated wi...  6619411
# 2418                      <cit id="6427966">[B13]</cit>  6427966
# 2419  <cit id="6427966">[B13]</cit>1662 The followin...  6427966
# 2420  <cit id="6427966">[B13]</cit> However, results...  6427966
# 2421                  <cit id="6427966">[B13]</cit>1564  6427966
# 2422  72 Since Corder et al.<cit id="6427966">[B13]<...  6427966
# 2423  Amyloid beta 40 is more prevalent and less tox...  6427966
# 2424  <cit id="6427966">[B49]</cit> Moreover, carrie...  6427966
# 2425  By IBS probing, one could identify people with...  6992384
# 2426  Genotypes of medical interest that are often i...  6992384
# 2427  SNP rs429358 is in the APOE locus; if a haplot...  6992384
# 2428  The greatest genetic risk factor for developin...  6491037
# 2429  Whatever the precise mechanism, APOE-ɛ4 carrie...  6491037
# 2430  Whatever the precise mechanism, APOE-ɛ4 carrie...  6491037
# 2431  The most important of these is Apolipoprotein ...  6261251
# 2432  The effect of ApoE4 on Aβ accumulation through...  6261251
# 2433  Early work following the seminal discovery of ...  6261251
# 2434  In the early 1990s, researchers discovered tha...  5634780
# 2435  These interactions with apolipoproteins are re...  5505701
# 2436  Apolipoprotein E (ApoE) ε4 genotype is the str...  3748711
# 2437  ApoE ε4 genotype strongly predisposes to an ea...  3748711
# 2438  Since stress is the major environmental risk f...  4862754
# 2439  The aforementioned cancer and psychology repli...  6688856
# 2440  Within the extracellular space, Aβ has, for in...  5505701
# 2441  From prospective heritability studies, it is c...  2901135
#
#              paper      pmc_id     pub_date pubmed_id
# 0           corder  PMC6883979  2019 Nov 12  31711277
# 1           corder  PMC6883979  2019 Nov 12  31711277
# 2           corder  PMC5638769  2017 Sep 20  28927263
# 3           corder  PMC4255096  2014 Oct 30  25358504
# 4     strittmatter  PMC6883979  2019 Nov 12  31711277
# 5     strittmatter  PMC6883979  2019 Nov 12  31711277
# 6     strittmatter  PMC5638769  2017 Sep 20  28927263
# 7            lesch  PMC6522375   2019 Jan 8  30622309
# 8            lesch  PMC6522375   2019 Jan 8  30622309
# 9            lesch  PMC3539149  2012 Jan 31  22290534
# 10           lesch  PMC4637001   2015 Nov 4  26537239
# 11           lesch  PMC3505534  2012 Jul 19  22810728
# 12           lesch  PMC3505534  2012 Jul 19  22810728
# 13           caspi  PMC2292755  2008 Apr 15  18416601
# 14          corder  PMC6497814   2019 Mar 4  30830563
# 15          corder  PMC4769573  2016 Feb 26  26919851
# 16          corder  PMC4769573  2016 Feb 26  26919851
# 17          corder  PMC4769573  2016 Feb 26  26919851
# 18          corder  PMC4769573  2016 Feb 26  26919851
# 19    strittmatter  PMC4769573  2016 Feb 26  26919851
# 20           lesch  PMC3405679   2012 Sep 5  22826345
# 21          corder  PMC4758402  2014 Aug 22  25155015
# 22          corder  PMC5425508  2017 Feb 14  28197669
# 23          corder  PMC5425508  2017 Feb 14  28197669
# 24          corder  PMC5425508  2017 Feb 14  28197669
# 25          corder  PMC5425508  2017 Feb 14  28197669
# 26          corder  PMC5425508  2017 Feb 14  28197669
# 27           caspi  PMC3809334  2013 May 18  23685902
# 28           lesch  PMC2792355  2005 Dec 27  16378243
# 29    strittmatter  PMC5425508  2017 Feb 14  28197669
# ...            ...         ...          ...       ...
# 2412        corder  PMC4437335  2013 Jan 27  26316992
# 2413        corder  PMC4437335  2013 Jan 27  26316992
# 2414  strittmatter  PMC4437336  2013 Mar 30  26316990
# 2415  strittmatter  PMC4437335  2013 Jan 27  26316992
# 2416        corder  PMC7179348  2019 Nov 15  32341985
# 2417         lesch  PMC6619411  2018 Aug 10  31294376
# 2418        corder  PMC6427966  2016 Sep 30  30906344
# 2419        corder  PMC6427966  2016 Sep 30  30906344
# 2420        corder  PMC6427966  2016 Sep 30  30906344
# 2421        corder  PMC6427966  2016 Sep 30  30906344
# 2422        corder  PMC6427966  2016 Sep 30  30906344
# 2423  strittmatter  PMC6427966  2016 Sep 30  30906344
# 2424  strittmatter  PMC6427966  2016 Sep 30  30906344
# 2425        corder  PMC6992384   2020 Jan 7  31908268
# 2426        corder  PMC6992384   2020 Jan 7  31908268
# 2427        corder  PMC6992384   2020 Jan 7  31908268
# 2428        corder  PMC6491037  2019 Apr 30  31038453
# 2429        corder  PMC6491037  2019 Apr 30  31038453
# 2430        corder  PMC6491037  2019 Apr 30  31038453
# 2431        corder  PMC6261251  2018 Oct 30  30375977
# 2432        corder  PMC6261251  2018 Oct 30  30375977
# 2433        corder  PMC6261251  2018 Oct 30  30375977
# 2434        corder  PMC5634780  2017 Oct 10  28994392
# 2435        corder  PMC5505701  2017 Jun 26  28650319
# 2436        corder  PMC3748711  2013 Aug 20  23986861
# 2437        corder  PMC3748711  2013 Aug 20  23986861
# 2438         caspi  PMC4862754  2016 May 10  27162170
# 2439         lesch  PMC6688856  2019 Jul 29  31355746
# 2440  strittmatter  PMC5505701  2017 Jun 26  28650319
# 2441         caspi  PMC2901135  2010 May 31  20631824
#
# [2442 rows x 25 columns]

# %%
### get summary statistics on the types of journals (citescores)
### where the positive, negative, and neutral citations come from

sentences_cs_df.groupby(['paper', 'cit_sent'])['CiteScore'].describe()
# Out:
#                        count      mean        std       min       25%  \
# paper        cit_sent
# caspi        NEGATIVE    2.0  6.844444   4.981174  3.322222  5.083333
#              NEUTRAL   233.0  7.876718   7.162908  0.611111  3.322222
#              POSITIVE   31.0  7.062590   5.242526  0.762500  4.922222
# corder       NEGATIVE    3.0  9.603704  10.083052  3.588889  3.783333
#              NEUTRAL   287.0  7.506403   5.698680  0.755556  3.977778
#              POSITIVE   36.0  7.317531   5.443367  1.166667  3.525000
# lesch        NEGATIVE    3.0  4.703704   2.407199  1.988889  3.766667
#              NEUTRAL   217.0  6.143463   4.408516  0.755556  3.188889
#              POSITIVE   28.0  6.347024   3.625344  1.466667  4.005556
# strittmatter NEGATIVE    0.0       NaN        NaN       NaN       NaN
#              NEUTRAL   119.0  7.923074   5.676605  1.255556  4.588889
#              POSITIVE    7.0  6.639683   4.933729  4.333333  4.655556
#
#                             50%        75%        max
# paper        cit_sent
# caspi        NEGATIVE  6.844444   8.605556  10.366667
#              NEUTRAL   6.522222   7.933333  51.788889
#              POSITIVE  5.477778   6.950000  21.244444
# corder       NEGATIVE  3.977778  12.611111  21.244444
#              NEUTRAL   5.344444   8.850000  50.611111
#              POSITIVE  5.022222   9.697222  22.522222
# lesch        NEGATIVE  5.544444   6.061111   6.577778
#              NEUTRAL   5.111111   7.144444  21.244444
#              POSITIVE  5.627778   8.266667  17.133333
# strittmatter NEGATIVE       NaN        NaN        NaN
#              NEUTRAL   5.311111   9.955556  22.522222
#              POSITIVE  4.822222   5.100000  17.811111

# %%
# look at distribution of negative, neutral, positive citations
pd.crosstab([sentences_cs_df['paper'], sentences_cs_df['cit_sent']], sentences_cs_df['Year'])
# Out:
# Year                   1995  1997  1999  2000  2001  2002  2003  2004  2005  \
# paper        cit_sent
# caspi        NEGATIVE     0     0     0     0     0     0     0     0     0
#              NEUTRAL      0     0     0     0     0     0     2     4     3
#              POSITIVE     0     0     0     0     0     0     0     1     0
# corder       NEGATIVE     0     0     0     0     0     0     0     0     0
#              NEUTRAL      1     1     1     1     1     0     3     4     5
#              POSITIVE     0     0     0     0     0     0     0     0     0
# lesch        NEGATIVE     0     0     0     0     0     0     0     0     0
#              NEUTRAL      0     0     0     0     2     6     1     6     7
#              POSITIVE     0     0     0     0     0     1     1     0     0
# strittmatter NEGATIVE     0     0     0     0     0     0     0     0     0
#              NEUTRAL      0     0     0     0     0     0     3     1     2
#              POSITIVE     0     0     0     0     0     0     0     1     0
#
# Year                   2006  ...   2011  2012  2013  2014  2015  2016  2017  \
# paper        cit_sent        ...
# caspi        NEGATIVE     0  ...      2     2     1     1     1     1     0
#              NEUTRAL     13  ...     22    37    61    56    58    45    60
#              POSITIVE     1  ...      2     4    11     2     7     7     7
# corder       NEGATIVE     1  ...      0     0     1     2     1     0     0
#              NEUTRAL      7  ...     34    37    58    51    59    87   103
#              POSITIVE     1  ...      2     8     2     8     6     5    13
# lesch        NEGATIVE     0  ...      0     1     0     0     1     0     0
#              NEUTRAL      4  ...     31    50    48    35    31    38    41
#              POSITIVE     0  ...      6     3    10     5     6     4     6
# strittmatter NEGATIVE     0  ...      0     0     0     1     0     0     0
#              NEUTRAL      1  ...     14    20    15    14    27    21    34
#              POSITIVE     1  ...      0     3     0     2     1     0     1
#
# Year                   2018  2019  2020
# paper        cit_sent
# caspi        NEGATIVE     0     0     0
#              NEUTRAL     46    61    35
#              POSITIVE     7     4     1
# corder       NEGATIVE     1     0     0
#              NEUTRAL    113   112    98
#              POSITIVE    13    14     6
# lesch        NEGATIVE     0     0     0
#              NEUTRAL     43    40    23
#              POSITIVE     4     1     2
# strittmatter NEGATIVE     0     0     0
#              NEUTRAL     38    30    25
#              POSITIVE     2     3     1
#
# [12 rows x 24 columns]

# %%
# create crosstab with year, paper, and sentiment
cite_year_df = pd.crosstab(sentences_cs_df['Year'], [sentences_cs_df['paper'], sentences_cs_df['cit_sent']])

# stack the results
cite_year_df = cite_year_df.stack(0).stack().reset_index()
# fix column name
cite_year_df = cite_year_df.rename(columns = {0:'Number of Cites'})

### do the same thing for cumulative totals
# create crosstab with year, paper, and sentiment
cite_sum_year_df = pd.crosstab([sentences_cs_df['paper'], sentences_cs_df['cit_sent']], sentences_cs_df['Year'])

#cite_sum_year_df
cite_sum_year_df = cite_sum_year_df.groupby(['paper', 'cit_sent']).apply(lambda x: x.cumsum(axis=1).sum())

# transpose for long dataset
cite_sum_year_df = cite_sum_year_df.transpose()

# stack the results
cite_sum_year_df = cite_sum_year_df.stack(0).stack().reset_index()
# fix column name
cite_sum_year_df = cite_sum_year_df.rename(columns = {0:'Number of Cites'})

# standardize the citations received per year by the total number of citations received throughout the period
#cite_year_df['% of Total Cites'] = 

cite_year_df['Pct of Total Cites'] = cite_year_df['Number of Cites'] / cite_year_df.groupby(['paper'])['Number of Cites'].transform('sum')

cite_year_df
# Out:
# C:\Users\tyler\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:4317: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   stacked_values = np.vstack(map(np.asarray, values))
#      Year         paper  cit_sent  Number of Cites  Pct of Total Cites
# 0    1995         caspi  NEGATIVE                0            0.000000
# 1    1995         caspi   NEUTRAL                0            0.000000
# 2    1995         caspi  POSITIVE                0            0.000000
# 3    1995        corder  NEGATIVE                0            0.000000
# 4    1995        corder   NEUTRAL                1            0.001076
# 5    1995        corder  POSITIVE                0            0.000000
# 6    1995         lesch  NEGATIVE                0            0.000000
# 7    1995         lesch   NEUTRAL                0            0.000000
# 8    1995         lesch  POSITIVE                0            0.000000
# 9    1995  strittmatter  NEGATIVE                0            0.000000
# 10   1995  strittmatter   NEUTRAL                0            0.000000
# 11   1995  strittmatter  POSITIVE                0            0.000000
# 12   1997         caspi  NEGATIVE                0            0.000000
# 13   1997         caspi   NEUTRAL                0            0.000000
# 14   1997         caspi  POSITIVE                0            0.000000
# 15   1997        corder  NEGATIVE                0            0.000000
# 16   1997        corder   NEUTRAL                1            0.001076
# 17   1997        corder  POSITIVE                0            0.000000
# 18   1997         lesch  NEGATIVE                0            0.000000
# 19   1997         lesch   NEUTRAL                0            0.000000
# 20   1997         lesch  POSITIVE                0            0.000000
# 21   1997  strittmatter  NEGATIVE                0            0.000000
# 22   1997  strittmatter   NEUTRAL                0            0.000000
# 23   1997  strittmatter  POSITIVE                0            0.000000
# 24   1999         caspi  NEGATIVE                0            0.000000
# 25   1999         caspi   NEUTRAL                0            0.000000
# 26   1999         caspi  POSITIVE                0            0.000000
# 27   1999        corder  NEGATIVE                0            0.000000
# 28   1999        corder   NEUTRAL                1            0.001076
# 29   1999        corder  POSITIVE                0            0.000000
# ..    ...           ...       ...              ...                 ...
# 258  2018         lesch  NEGATIVE                0            0.000000
# 259  2018         lesch   NEUTRAL               43            0.077617
# 260  2018         lesch  POSITIVE                4            0.007220
# 261  2018  strittmatter  NEGATIVE                0            0.000000
# 262  2018  strittmatter   NEUTRAL               38            0.128814
# 263  2018  strittmatter  POSITIVE                2            0.006780
# 264  2019         caspi  NEGATIVE                0            0.000000
# 265  2019         caspi   NEUTRAL               61            0.091867
# 266  2019         caspi  POSITIVE                4            0.006024
# 267  2019        corder  NEGATIVE                0            0.000000
# 268  2019        corder   NEUTRAL              112            0.120560
# 269  2019        corder  POSITIVE               14            0.015070
# 270  2019         lesch  NEGATIVE                0            0.000000
# 271  2019         lesch   NEUTRAL               40            0.072202
# 272  2019         lesch  POSITIVE                1            0.001805
# 273  2019  strittmatter  NEGATIVE                0            0.000000
# 274  2019  strittmatter   NEUTRAL               30            0.101695
# 275  2019  strittmatter  POSITIVE                3            0.010169
# 276  2020         caspi  NEGATIVE                0            0.000000
# 277  2020         caspi   NEUTRAL               35            0.052711
# 278  2020         caspi  POSITIVE                1            0.001506
# 279  2020        corder  NEGATIVE                0            0.000000
# 280  2020        corder   NEUTRAL               98            0.105490
# 281  2020        corder  POSITIVE                6            0.006459
# 282  2020         lesch  NEGATIVE                0            0.000000
# 283  2020         lesch   NEUTRAL               23            0.041516
# 284  2020         lesch  POSITIVE                2            0.003610
# 285  2020  strittmatter  NEGATIVE                0            0.000000
# 286  2020  strittmatter   NEUTRAL               25            0.084746
# 287  2020  strittmatter  POSITIVE                1            0.003390
#
# [288 rows x 5 columns]

# %% [markdown]
# ## Figures

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

#set axes to numeric
cite_year_df['Year'] = pd.to_numeric(cite_year_df['Year'], errors = 'coerce')

# create line plots
lineplot = sns.lineplot(data=cite_year_df, style = 'paper', hue = 'cit_sent', x = 'Year', y = 'Number of Cites')

lineplot.set_title("Citation Sentiments for Selected Papers")
# Out:
# Text(0.5,1,'Citation Sentiments for Selected Papers')

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

#set axes to numeric
cite_year_df['Year'] = pd.to_numeric(cite_year_df['Year'], errors = 'coerce')

# create line plots
lineplot = sns.lineplot(data=cite_year_df, style = 'paper', hue = 'cit_sent', x = 'Year', y = 'Pct of Total Cites')

lineplot.set_title("Citation Sentiments for Selected Papers")
# Out:
# Text(0.5,1,'Citation Sentiments for Selected Papers')

# %%
#set axes to numeric
cite_sum_year_df['Year'] = pd.to_numeric(cite_sum_year_df['Year'], errors = 'coerce')

# cunulative version
lineplot = sns.lineplot(data=cite_sum_year_df, style = 'paper', hue = 'cit_sent', x = 'Year', y = 'Number of Cites')

lineplot.set_title("Cumulative Citation Sentiments for Selected Papers")
# Out:
# Text(0.5,1,'Cumulative Citation Sentiments for Selected Papers')

# %%
#search_citescores_df.columns

sns.distplot(sentences_cs_df['Year'],
             kde=False).set_title("Frequency of Articles citing Selected Papers")
# Out:
# Text(0.5,1,'Frequency of Articles citing Selected Papers')

# %%
### get summary statistics on the types of journals (citescores)
### where the positive, negative, and neutral citations come from

sentences_cs_df.groupby('Year')['CiteScore'].describe()


# convert year to number
sentences_cs_df['Year'] = pd.to_numeric(sentences_cs_df['Year'], errors = 'coerce')

lineplot = sns.lineplot(x="Year", y="CiteScore", hue = 'paper',
             data=sentences_cs_df.drop_duplicates('pubmed_id'))

lineplot.set_title("Impact of Journals with articles citing Selected Papers")
# Out:
# Text(0.5,1,'Impact of Journals with articles citing Selected Papers')

# %%
# proportion of articles with NO citescore, over time 
sentences_cs_df['no_citescore']  = sentences_cs_df['CiteScore'].isna()*1
sentences_cs_df

sentences_cs_df.groupby('Year')['CiteScore'].describe()

lineplot = sns.lineplot(x="Year", y="no_citescore", hue = 'paper',
                        data=sentences_cs_df.drop_duplicates('pubmed_id'))

lineplot.set_title("Percent of Journals citing Selected Papers with no CiteScore")
# Out:
# Text(0.5,1,'Percent of Journals citing Selected Papers with no CiteScore')
